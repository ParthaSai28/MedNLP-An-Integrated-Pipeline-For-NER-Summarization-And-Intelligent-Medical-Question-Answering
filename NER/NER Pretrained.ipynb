# %%
import spacy
from spacy import displacy
import IPython

from collections import defaultdict

# %%
from IPython.display import display, HTML

# %%
mednlp = spacy.load("en_core_med7_lg")        # Med7 model
bionlp = spacy.load("en_ner_bionlp13cg_md")   # BioNLP13CG model
bc5cdr_nlp = spacy.load("en_ner_bc5cdr_md")   # BC5CDR model
# Out:
# C:\Users\PARTHA\AppData\Roaming\Python\Python39\site-packages\spacy\util.py:910: UserWarning: [W095] Model 'en_core_med7_lg' (3.4.2.1) was trained with spaCy v3.4.2 and may not be 100% compatible with the current version (3.7.5). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# C:\Users\PARTHA\AppData\Roaming\Python\Python39\site-packages\spacy\language.py:2195: FutureWarning: Possible set union at position 6328
#   deserializers["tokenizer"] = lambda p: self.tokenizer.from_disk(  # type: ignore[union-attr]

# %%
text = """
This 23-year-old white female presents with complaint of allergies. She used to have allergies when she lived in Seattle but she thinks they are worse here. In the past, she has tried Claritin, and Zyrtec. Both worked for short time but then seemed to lose effectiveness. She has used Allegra also. She used that last summer and she began using it again two weeks ago. It does not appear to be working very well. She has used over-the-counter sprays but no prescription nasal sprays. She does have asthma but doest not require daily medication for this and does not think it is flaring up.
Her only medication currently is Ortho Tri-Cyclen and the Allegra.
She has no known medicine allergies.
Vitals: Weight was 130 pounds and blood pressure 124/78.
HEENT: Her throat was mildly erythematous without exudate. Nasal mucosa was erythematous and swollen. Only clear drainage was seen. TMs were clear.
Neck: Supple without adenopathy.
Lungs: Clear.
Allergic rhinitis.
1. She will try Zyrtec instead of Allegra again. Another option will be to use loratadine. She does not think she has prescription coverage so that might be cheaper.
2. Samples of Nasonex two sprays in each nostril given for three weeks. A prescription was written as well.
"""

# %%
doc_med7 = mednlp(text)
doc_bionlp = bionlp(text)
doc_bc5cdr = bc5cdr_nlp(text)

# %%
def render_entities(doc, model_name):
    html = displacy.render(doc, style="ent", jupyter=False)
    return f"<h3>{model_name}</h3>" + html

# %%
html_output = f"""
<div style="display: flex; gap: 30px;">
    <div style="flex: 1;">{render_entities(doc_med7, "Med7")}</div>
    <div style="flex: 1;">{render_entities(doc_bionlp, "BioNLP13CG")}</div>
    <div style="flex: 1;">{render_entities(doc_bc5cdr, "BC5CDR")}</div>
</div>
"""
display(HTML(html_output))
# Out:
# <div style="display: flex; gap: 30px;">
#     <div style="flex: 1;"><h3>Med7</h3><div class="entities" style="line-height: 2.5; direction: ltr"><br>This 23-year-old white female presents with complaint of allergies. She used to have allergies when she lived in Seattle but she thinks they are worse here. In the past, she has tried
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Claritin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DRUG</span>
# </mark>
# , and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zyrtec
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DRUG</span>
# </mark>
# . Both worked for short time but then seemed to lose effectiveness. She has used Allegra also. She used that last summer and she began using it again two weeks ago. It does not appear to be working very well. She has used over-the-counter sprays but no prescription nasal sprays. She does have asthma but doest not require
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     daily
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FREQUENCY</span>
# </mark>
#  medication for this and does not think it is flaring up.<br>Her only medication currently is Ortho Tri-Cyclen and the Allegra.<br>She has no known medicine allergies.<br>Vitals: Weight was 130 pounds and blood pressure 124/78.<br>HEENT: Her throat was mildly erythematous without exudate. Nasal mucosa was erythematous and swollen. Only clear drainage was seen. TMs were clear.<br>Neck: Supple without adenopathy.<br>Lungs: Clear.<br>Allergic rhinitis.<br>1. She will try
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zyrtec
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DRUG</span>
# </mark>
#  instead of Allegra again. Another option will be to use
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     loratadine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DRUG</span>
# </mark>
# . She does not think she has prescription coverage so that might be cheaper.<br>2. Samples of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nasonex
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DRUG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DOSAGE</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sprays
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FORM</span>
# </mark>
#  in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     each
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DOSAGE</span>
# </mark>
#  nostril given
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     for three weeks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DURATION</span>
# </mark>
# . A prescription was written as well.<br></div></div>
#     <div style="flex: 1;"><h3>BioNLP13CG</h3><div class="entities" style="line-height: 2.5; direction: ltr"><br>This 23-year-old white
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     female
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORGANISM</span>
# </mark>
#  presents with complaint of allergies. She used to have allergies when she lived in Seattle but she thinks they are worse here. In the past, she has tried
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Claritin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SIMPLE_CHEMICAL</span>
# </mark>
# , and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zyrtec
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SIMPLE_CHEMICAL</span>
# </mark>
# . Both worked for short time but then seemed to lose effectiveness. She has used Allegra also. She used that last summer and she began using it again two weeks ago. It does not appear to be working very well. She has used over-the-counter sprays but no prescription
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nasal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MULTI_TISSUE_STRUCTURE</span>
# </mark>
#  sprays. She does have asthma but doest not require daily medication for this and does not think it is flaring up.<br>Her only medication currently is Ortho Tri-Cyclen and the Allegra.<br>She has no known medicine allergies.<br>Vitals: Weight was 130 pounds and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     blood
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORGANISM_SUBSTANCE</span>
# </mark>
#  pressure 124/78.<br>HEENT: Her throat was mildly
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     erythematous
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORGANISM_SUBDIVISION</span>
# </mark>
#  without
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     exudate
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TISSUE</span>
# </mark>
# .
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nasal mucosa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MULTI_TISSUE_STRUCTURE</span>
# </mark>
#  was erythematous and swollen. Only clear drainage was seen.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TMs
#     <span style="font-size: 0.8em; font-weight: bold; line-heigh

# %%
def get_entity_groups(t):
    # doc_med = mednlp(t)
    doc_bio = bionlp(t)
    doc_bc5 = bc5cdr_nlp(t)

    d = defaultdict(list)
    # for e in doc_med.ents:
    #     d[e.label_].append(e.text)
    for e in doc_bio.ents:
        d[e.label_].append(e.text)
    for e in doc_bc5.ents:
        d[e.label_].append(e.text)

    return sorted(d.items())

# %%
entities = get_entity_groups(text)

# %%
entities
# Out:
# [('CANCER', ['COPD']),
#  ('CHEMICAL', ['amoxicillin', 'salbutamol', 'fluticasone']),
#  ('DISEASE',
#   ['throat infection',
#    'asthma',
#    'chronic obstructive pulmonary disease',
#    'COPD']),
#  ('IMMATERIAL_ANATOMICAL_ENTITY', ['inhaler']),
#  ('ORGAN', ['pulmonary']),
#  ('ORGANISM', ['patient']),
#  ('SIMPLE_CHEMICAL', ['amoxicillin', 'salbutamol', 'fluticasone'])]

# %%
from transformers import pipeline
from IPython.display import display, HTML

ner_pipe = pipeline("ner", model="d4sdata/biomedical-ner-all", aggregation_strategy="simple")

text = """
This 23-year-old white female presents with complaint of allergies. She used to have allergies when she lived in Seattle but she thinks they are worse here. In the past, she has tried Claritin, and Zyrtec. Both worked for short time but then seemed to lose effectiveness. She has used Allegra also. She used that last summer and she began using it again two weeks ago. It does not appear to be working very well. She has used over-the-counter sprays but no prescription nasal sprays. She does have asthma but doest not require daily medication for this and does not think it is flaring up.
Her only medication currently is Ortho Tri-Cyclen and the Allegra.
She has no known medicine allergies.
Vitals: Weight was 130 pounds and blood pressure 124/78.
HEENT: Her throat was mildly erythematous without exudate. Nasal mucosa was erythematous and swollen. Only clear drainage was seen. TMs were clear.
Neck: Supple without adenopathy.
Lungs: Clear.
Allergic rhinitis.
1. She will try Zyrtec instead of Allegra again. Another option will be to use loratadine. She does not think she has prescription coverage so that might be cheaper.
2. Samples of Nasonex two sprays in each nostril given for three weeks. A prescription was written as well.
"""

ner_results = ner_pipe(text)

def highlight_entities(text, entities):
    entities = sorted(entities, key=lambda x: x['start'])
    last_idx = 0
    html = ""

    for ent in entities:
        start, end = ent['start'], ent['end']
        label = ent['entity_group']
        entity_text = text[start:end]
        html += text[last_idx:start]
        html += f'<mark style="background-color: #dddddd; padding: 4px 4px; border-radius: 4px;">{entity_text} <b>{label}</b></mark>'
        last_idx = end
        
    html += text[last_idx:]
    return html

html_output = highlight_entities(text, ner_results)
display(HTML(f"<div style='font-family:Arial; font-size: 15px;'>{html_output}</div>"))
# Out:
# Device set to use cuda:0
# <div style='font-family:Arial; font-size: 15px;'>
# This <mark style="background-color: #dddddd; padding: 4px 4px; border-radius: 4px;">23-year-old <b>Age</b></mark> <mark style="background-color: #dddddd; padding: 4px 4px; border-radius: 4px;">white <b>Personal_background</b></mark> <mark style="background-color: #dddddd; padding: 4px 4px; border-radius: 4px;">female <b>Sex</b></mark> <mark style="background-color: #dddddd; padding: 4px 4px; border-radius: 4px;">presents <b>Clinical_event</b></mark> with complaint of allergies. She used to have <mark style="background-color: #dddddd; padding: 4px 4px; border-radius: 4px;">all <b>Disease_disorder</b></mark><mark style="background-color: #dddddd; padding: 4px 4px; border-radius: 4px;">ergies <b>Sign_symptom</b></mark> when she lived in <mark style="background-color: #dddddd; padding: 4px 4px; border-radius: 4px;">Seattle <b>Nonbiological_location</b></mark> but she thinks they are worse here. In the past, she has tried Claritin, and Zyrtec. Both worked for short time but then seemed to lose effectiveness. She has used Allegra also. She used that last <mark style="background-color: #dddddd; padding: 4px 4px; border-radius: 4px;">summer <b>Duration</b></mark> and she began using it again <mark style="background-color: #dddddd; padding: 4px 4px; border-radius: 4px;">two <b>Duration</b></mark> weeks ago. It does not appear to be working very well. She has used over-the-<mark style="background-color: #dddddd; padding: 4px 4px; border-radius: 4px;">counter <b>Detailed_description</b></mark> sprays but no prescription nasal sprays. She does have <mark style="background-color: #dddddd; padding: 4px 4px; border-radius: 4px;">asthma <b>History</b></mark> but doest not require <mark style="background-color: #dddddd; padding: 4px 4px; border-radius: 4px;">daily <b>Frequency</b></mark> medication for this and does not think it is flaring up.
# Her only medication currently is <mark style="background-color: #dddddd; padding: 4px 4px; border-radius: 4px;">Or <b>Medication</b></mark>tho Tri-<mark style="background-color: #dddddd; padding: 4px 4px; border-radius: 4px;">Cycle <b>Medication</b></mark>n and the Allegra.
# She has no known medicine allergies.
# <mark style="background-color: #dddddd; padding: 4px 4px; border-radius: 4px;">Vital <b>Diagnostic_procedure</b></mark>s: <mark style="background-color: #dddddd; padding: 4px 4px; border-radius: 4px;">Weight <b>Diagnostic_procedure</b></mark> was <mark style="background-color: #dddddd; padding: 4px 4px; border-radius: 4px;">130 pounds <b>Lab_value</b></mark> and <mark style="background-color: #dddddd; padding: 4px 4px; border-radius: 4px;">blood pressure <b>Diagnostic_procedure</b></mark> <mark style="background-color: #dddddd; padding: 4px 4px; border-radius: 4px;">124/ <b>Lab_value</b></mark>78.
# HEENT: Her <mark style="background-color: #dddddd; padding: 4px 4px; border-radius: 4px;">throat <b>Biological_structure</b></mark> was mildly <mark style="background-color: #dddddd; padding: 4px 4px; border-radius: 4px;">erythematous <b>Sign_symptom</b></mark> without exudate. <mark style="background-color: #dddddd; padding: 4px 4px; border-radius: 4px;">Nasal mucosa <b>Biological_structure</b></mark> was <mark style="background-color: #dddddd; padding: 4px 4px; border-radius: 4px;">er <b>Sign_symptom</b></mark>ythematous and swollen. Only clear drainage was seen. TMs were clear.
# Neck: Supple without adenopathy.
# Lungs: Clear.
# Allergic rhinitis.
# 1. She will try Zyrtec instead of <mark style="background-color: #dddddd; padding: 4px 4px; border-radius: 4px;">All <b>Medication</b></mark>egra again. Another option will be to use loratadine. She does not think she has prescription coverage so that might be cheaper.
# 2. Samples of <mark style="background-color: #dddddd; padding: 4px 4px; border-radius: 4px;">Nasonex <b>Medication</b></mark> two sprays in each <mark style="background-color: #dddddd; padding: 4px 4px; border-radius: 4px;">nos <b>Biological_structure</b></mark><mark style="background-color: #dddddd; padding: 4px 4px; border-radius: 4px;">tril <b>Biological_structure</b></mark> given for three weeks. A prescription was written as well.
# </div>
